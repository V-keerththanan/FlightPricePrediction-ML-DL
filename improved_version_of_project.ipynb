# %% [markdown]
# <a href="https://colab.research.google.com/github/V-keerththanan/FlightPricePrediction-ML-DL/blob/master/improved_version_of_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load the data and cleaning the data

# %%
url="https://github.com/V-keerththanan/FlightPricePrediction-ML-DL/blob/master/Data_Train.xlsx?raw=true"

# %%
df= pd.read_excel(url)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# shuffle the data

# %%
shuffled_df = shuffle(df, random_state=42)

# %%
shuffled_df.head()
# Out:
#           Airline Date_of_Journey   Source Destination            Route  \
# 6076  Jet Airways      18/05/2019  Kolkata    Banglore  CCU → BOM → BLR
# 3544        GoAir       3/06/2019    Delhi      Cochin  DEL → BOM → COK
# 7313  Jet Airways       1/05/2019  Kolkata    Banglore  CCU → BOM → BLR
# 5032       IndiGo      24/05/2019  Chennai     Kolkata        MAA → CCU
# 2483  Jet Airways      21/05/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 6076    05:45         18:15  12h 30m      1 stop  In-flight meal not included
# 3544    10:35         19:35       9h      1 stop                      No info
# 7313    14:05         19:50   5h 45m      1 stop                      No info
# 5032    14:45         17:05   2h 20m    non-stop                      No info
# 2483    22:50  04:25 22 May   5h 35m      1 stop  In-flight meal not included
#
#       Price
# 6076  10844
# 3544   4959
# 7313  14781
# ...

# %%
df= shuffled_df

# %% [markdown]
# drop duplicate

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# there is only 2 null values , so removing null values

# %%
df.dropna(inplace=True)

# %% [markdown]
# splitting the data

# %%
X=df.drop(['Price'],axis=1)
y=df['Price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.85,random_state=0)

# %%
print(len(X_train))
print("---")
print(len(y_train))
# Out:
# 8892
# ---
# 8892

# %%
X_train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# Change the Duration column , h to m

# %%
# 12h 30m
def changeDurationFormate(duration:str):
  result=duration.split()
  if len(result)==2:
    h=int(result[0][0:-1])
    m=int(result[1][0:-1])
    return h*60+m
  else:
    if 'h' in result[0]:
      h=int(result[0][0:-1])*60
      return h
    else:
      m=int(result[0][0:-1])
      return m

# %%
changeDurationFormate("12h 30m")
# Out:
# 750

# %%
def cleanDuration(data:pd.DataFrame):
  duration=data['Duration']
  return duration.apply(changeDurationFormate)

# %%
X_train['Duration']=cleanDuration(X_train)
X_test['Duration']=cleanDuration(X_test)

# %%
X_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 2906        Jet Airways      21/05/2019     Delhi      Cochin
# 9652  Multiple carriers      12/06/2019     Delhi      Cochin
# 618            Air Asia       3/05/2019  Banglore       Delhi
# 2636              GoAir      18/05/2019   Kolkata    Banglore
# 6130             IndiGo      24/05/2019   Kolkata    Banglore
# ...                 ...             ...       ...         ...
# 6671          Air India      24/03/2019   Kolkata    Banglore
# 9667              GoAir       3/03/2019     Delhi      Cochin
# 1294          Air India       6/06/2019   Kolkata    Banglore
# 7227        Jet Airways       3/06/2019     Delhi      Cochin
# 8808             IndiGo      21/06/2019   Chennai     Kolkata
#
#                 Route Dep_Time  Arrival_Time  Duration Total_Stops  \
# 2906  DEL → BOM → COK    16:00  19:00 22 May      1620      1 stop
# 9652  DEL → BOM → COK    13:00  01:30 13 Jun       750      1 stop
# ...

# %% [markdown]
# ### Feature Extraction & Engineering

# %% [markdown]
# Extract hour&minute from Dep_Time but drop Arrival time, because we already have Duration so Dep_time+duration=Arrival_Time

# %%
X_train.drop('Arrival_Time',axis=1,inplace=True)
X_test.drop('Arrival_Time',axis=1,inplace=True)

# %%
X_test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Duration', 'Total_Stops', 'Additional_Info'],
#       dtype='object')

# %%
X_train['Dep_Time'][0].split(":")[0]
# Out:
# '22'

# %%
def extractInfoFromDepTime(data:pd.DataFrame):
  data['Dept_Time_H']=data['Dep_Time'].apply(lambda x:int(x.split(":")[0]))
  data['Dept_Time_M']=data['Dep_Time'].apply(lambda x:int(x.split(":")[1]))
  data.drop('Dep_Time',axis=1,inplace=True)

# %%
extractInfoFromDepTime(X_train)
extractInfoFromDepTime(X_test)

# %%
X_test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Dept_Time_H',
#        'Dept_Time_M'],
#       dtype='object')

# %%
X_test.head(5)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 2906        Jet Airways      21/05/2019     Delhi      Cochin
# 9652  Multiple carriers      12/06/2019     Delhi      Cochin
# 618            Air Asia       3/05/2019  Banglore       Delhi
# 2636              GoAir      18/05/2019   Kolkata    Banglore
# 6130             IndiGo      24/05/2019   Kolkata    Banglore
#
#                 Route  Duration Total_Stops Additional_Info  Dept_Time_H  \
# 2906  DEL → BOM → COK      1620      1 stop         No info           16
# 9652  DEL → BOM → COK       750      1 stop         No info           13
# 618         BLR → DEL       170    non-stop         No info            4
# 2636  CCU → BOM → BLR       495      1 stop         No info           23
# 6130        CCU → BLR       155    non-stop         No info           20
#
#       Dept_Time_M
# 2906            0
# 9652            0
# 618            55
# 2636           30
# 6130           20

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1570 entries, 2906 to 8808
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          1570 non-null   object
#  1   Date_of_Journey  1570 non-null   object
#  2   Source           1570 non-null   object
#  3   Destination      1570 non-null   object
#  4   Route            1570 non-null   object
#  5   Duration         1570 non-null   int64
#  6   Total_Stops      1570 non-null   object
#  7   Additional_Info  1570 non-null   object
#  8   Dept_Time_H      1570 non-null   int64
#  9   Dept_Time_M      1570 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 134.9+ KB

# %% [markdown]
# extract month,day,year from Date of Journey

# %%
def extractInfoFromDateOfJourney(data:pd.DataFrame):
  data['Date_of_Journey_day']=data['Date_of_Journey'].apply(lambda x:int(str(x).split("/")[0]))
  data['Date_of_Journey_month']=data['Date_of_Journey'].apply(lambda x:int(str(x).split("/")[1]))
  data['Date_of_Journey_year']=data['Date_of_Journey'].apply(lambda x:int(str(x).split("/")[2]))
  data.drop('Date_of_Journey',axis=1,inplace=True)

# %%
extractInfoFromDateOfJourney(X_train)
extractInfoFromDateOfJourney(X_test)

# %%
X_train.head(5)
# Out:
#           Airline    Source Destination                  Route  Duration  \
# 6157  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK      1060
# 9561       IndiGo  Banglore       Delhi              BLR → DEL       180
# 9433  Jet Airways   Kolkata    Banglore        CCU → BOM → BLR       705
# 4509       IndiGo   Chennai     Kolkata              MAA → CCU       145
# 8775     SpiceJet    Mumbai   Hyderabad              BOM → HYD        90
#
#      Total_Stops               Additional_Info  Dept_Time_H  Dept_Time_M  \
# 6157     2 stops                       No info           10           45
# 9561    non-stop                       No info           16           55
# 9433      1 stop                       No info            6           30
# 4509    non-stop                       No info            5           15
# 8775    non-stop  No check-in baggage included           13           15
#
#       Date_of_Journey_day  Date_of_Journey_month  Date_of_Journey_year
# ...
